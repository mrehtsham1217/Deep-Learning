# %% [markdown]
# # Problems with Perceptron

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['ouput']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      0
# 2       0       1      0
# 3       0       0      0

# %%
# sn.scatterplot(and_data['input1'],and_data['input2'],hue=and_data['ouput'],s=200)
plt.scatter(and_data['input1'],and_data['input2'],c=and_data['ouput'],cmap='winter',s=200)
plt.show()

# %%
plt.scatter(or_data['input1'],or_data['input2'],c=or_data['ouput'],cmap='winter',s=200)
plt.show()

# %%
plt.scatter(xor_data['input1'],xor_data['input2'],c=xor_data['ouput'],cmap='winter',s=200)
plt.show()

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
print(clf1.coef_)
print(clf1.intercept_)
# Out:
# [[2. 2.]]
# [-2.]

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
plt.scatter(and_data['input1'],and_data['input2'],c=and_data['ouput'],s=200)
plt.show()

# %%
print(clf2.coef_)
print(clf2.intercept_)
# Out:
# [[2. 2.]]
# [-1.]

# %%
plt.plot(x,y)
plt.scatter(or_data['input1'],or_data['input2'],c=or_data['ouput'],s=200)
plt.show()

# %%
print(clf3.coef_)
print(clf3.intercept_)
# Out:
# [[0. 0.]]
# [0.]

# %%
plt.plot(x,y)
plt.scatter(xor_data['input1'],xor_data['input2'],c=xor_data['ouput'],s=200)
